# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('../data/meta_content.csv', converters={'category': eval, 'also_buy': eval, 'feature': eval,'also_view': eval, 'details': eval})
df1.head()
# Out:
#                 category                                        description
# 0  [Movies & TV, Movies]                                                NaN  \
# 1  [Movies & TV, Movies]                                                NaN
# 2  [Movies & TV, Movies]  Disc 1: Flour Power (Scones; Shortcakes; South...
# 3  [Movies & TV, Movies]  Barefoot Contessa Volume 2: On these three dis...
# 4  [Movies & TV, Movies]  Rise and Swine (Good Eats Vol. 7) includes bon...
#
#                                                title
# 0                Understanding Seizures and Epilepsy  \
# 1  Spirit Led&mdash;Moving By Grace In The Holy S...
# 2                  My Fair Pastry (Good Eats Vol. 9)
# 3  Barefoot Contessa (with Ina Garten), Entertain...
# 4                  Rise and Swine (Good Eats Vol. 7)
#
#                                             also_buy        brand feature
# 0                                                 []          NaN      []  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181839 entries, 0 to 181838
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   category     181839 non-null  object
#  1   description  156721 non-null  object
#  2   title        181781 non-null  object
#  3   also_buy     181839 non-null  object
#  4   brand        120867 non-null  object
#  5   feature      181839 non-null  object
#  6   rank         181839 non-null  object
#  7   also_view    181839 non-null  object
#  8   asin         181839 non-null  object
#  9   details      181839 non-null  object
# dtypes: object(10)
# memory usage: 13.9+ MB

# %%
df = df1.copy()

# %%
df_all = pd.read_csv('../data/review_allvid_clean.csv')
df_all.head()
# Out:
#    rating         user_id    movie_id
# 0       5  A2VHSG6TZHU1OB  0001527665  \
# 1       5  A1KM9FNEJ8Q171  0001527665
# 2       4  A38LY2SSHVHRYB  0001527665
# 3       5   AHTYUW2H1276L  0001527665
# 4       5  A3M3HCZLXW0YLF  0001527665
#
#                                              reviews
# 0  Having lived in West New Guinea (Papua) during...
# 1  More than anything, I've been challenged to fi...
# 2  This is a great movie for a missionary going i...
# 3  This movie was in ENGLISH....it was a great su...
# 4  This is a fascinating true story, well acted b...

# %%
df_prime = pd.read_csv('./data/reviews_streaming.csv')
df_prime.head()
# Out:
#    overall   reviewTime      reviewerID        asin
# 0        5  10 24, 2017  A235CSFIMYI5JK  B00SU1DDVY  \
# 1        5  05 15, 2017  A1H41LX36UOWYA  B00SU1DDVY
# 2        5   04 3, 2017  A1TSMQSMIREU02  B00SU1DDVY
# 3        5  08 15, 2016  A2K62IHNYD9CBR  B00SU1DDVY
# 4        5  05 27, 2016   AOGNYFSGIZGT4  B00SU1DDVY
#
#                                           reviewText
# 0  I love this movie. This man was awesome. Super...  \
# 1  I love this movie.  I first saw it on Netflix ...
# 2  This movie was a great adventure despite havin...
# 3                Must have watched five times by now
# 4  Absolutely astounding and moving. Shows how ba...
#
#                                              summary  vote
# 0                                  I love this movie   0.0
# 1                                              Movie   0.0
# 2                                         Five Stars   0.0
# 3                                         Five Stars   0.0
# ...

# %%
df_amvid = pd.read_csv('./data/reviews_amstream.csv')
df_amvid.head()
# Out:
#    overall   reviewTime      reviewerID        asin
# 0        5  02 18, 2013  A2VHSG6TZHU1OB  0001527665  \
# 1        5  01 10, 2013  A1KM9FNEJ8Q171  0001527665
# 2        4  12 26, 2012  A38LY2SSHVHRYB  0001527665
# 3        5  11 16, 2012   AHTYUW2H1276L  0001527665
# 4        5  07 15, 2012  A3M3HCZLXW0YLF  0001527665
#
#                                           reviewText
# 0  Having lived in West New Guinea (Papua) during...  \
# 1  More than anything, I've been challenged to fi...
# 2  This is a great movie for a missionary going i...
# 3  This movie was in ENGLISH....it was a great su...
# 4  This is a fascinating true story, well acted b...
#
#                                              summary  vote
# 0                             Realistic and Accurate   3.0
# 1  Culturally relevant ways to share the love of ...   0.0
# 2  Good Movie! Great for cross-cultural missionar...   0.0
# 3                                          Great....   3.0
# ...

# %%
all_streams = df_all['movie_id'].unique().tolist()

# %%
all_streams = df_all['asin'].unique().tolist()
amvid_streams = df_amvid['asin'].unique().tolist()
prime_streams = df_prime['asin'].unique().tolist()

# %%
df_all_filt = df[df['asin'].isin(all_streams)]
df_all_filt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 127467 entries, 3 to 181836
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   category     127467 non-null  object
#  1   description  115349 non-null  object
#  2   title        127434 non-null  object
#  3   also_buy     127467 non-null  object
#  4   brand        93872 non-null   object
#  5   feature      127467 non-null  object
#  6   rank         127467 non-null  object
#  7   also_view    127467 non-null  object
#  8   asin         127467 non-null  object
#  9   details      127467 non-null  object
# dtypes: object(10)
# memory usage: 10.7+ MB

# %%
df_amvid_filt = df[df['asin'].isin(amvid_streams)]
df_amvid_filt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25762 entries, 13 to 170092
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   category     25762 non-null  object
#  1   description  23945 non-null  object
#  2   title        25761 non-null  object
#  3   also_buy     25762 non-null  object
#  4   brand        22760 non-null  object
#  5   feature      25762 non-null  object
#  6   rank         25762 non-null  object
#  7   also_view    25762 non-null  object
#  8   asin         25762 non-null  object
#  9   details      25762 non-null  object
# dtypes: object(10)
# memory usage: 2.2+ MB

# %%
df_prime_filt = df[df['asin'].isin(prime_streams)]
df_prime_filt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2374 entries, 3154 to 181832
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   category     2374 non-null   object
#  1   description  2260 non-null   object
#  2   title        2374 non-null   object
#  3   also_buy     2374 non-null   object
#  4   brand        2076 non-null   object
#  5   feature      2374 non-null   object
#  6   rank         2374 non-null   object
#  7   also_view    2374 non-null   object
#  8   asin         2374 non-null   object
#  9   details      2374 non-null   object
# dtypes: object(10)
# memory usage: 204.0+ KB

# %%
df_prime_filt.to_csv('./data/meta_streams.csv', encoding='utf-8', index=False)

# %%
df_test = pd.read_csv('./data/meta_streams.csv', converters={'category': eval, 'also_buy': eval, 'feature': eval,'also_view': eval, 'details': eval})
df_test.head()
# Out:
#                                             category
# 0  [Movies & TV, Genre for Featured Categories, A...  \
# 1  [Movies & TV, Genre for Featured Categories, C...
# 2  [Movies & TV, Genre for Featured Categories, C...
# 3  [Movies & TV, Musicals & Performing Arts, Musi...
# 4  [Movies & TV, Genre for Featured Categories, S...
#
#                                          description
# 0  Kids on an outing in the forest come up agains...  \
# 1  Alberto (Oscar Jaenada, Noviembre) and Susana ...
# 2  A hard nosed FBI agent and her dim witted part...
# 3  Competition is hot in the rodeo business as we...
# 4  VILLE DE QUEBEC On behalf of the French crown,...
#
#                                 title also_buy
# 0               Bridge to Nowhere VHS       []  \
# 1               El Juego De La Verdad       []
# 2                   Nosferatu's Crush       []
# 3       Lights From Old Sante Fe 1944       []
# 4  Vista Point  Town Of QUEBEC Canada       []
#
# ...

# %%
df_test['category'].apply(type).unique()
# Out:
# array([<class 'list'>], dtype=object)

# %%
df_all_filt.to_csv('../data/meta_allvid.csv', encoding='utf-8', index=False)

# %%
df_test2 = pd.read_csv('./data/meta_allstreams.csv', converters={'category': eval, 'also_buy': eval, 'feature': eval,'also_view': eval, 'details': eval})
df_test2.head()
# Out:
#                                             category
# 0  [Movies & TV, Art House & International, By Or...  \
# 1            [Movies & TV, Christian Video, General]
# 2                              [Movies & TV, Movies]
# 3  [Movies & TV, Independently Distributed, Docum...
# 4  [Movies & TV, Science Fiction & Fantasy, Scien...
#
#                                          description
# 0                                                NaN  \
# 1       An early movie edition of the life of Jesus.
# 2  In Depression-era New England, a miserly busin...
# 3  This documentary takes you on a journey...from...
# 4  This is The VHS Movie: SANTA CLAUS IS COMIN TO...
#
#                                                title
# 0                                    Peace Child VHS  \
# 1                             Where Jesus Walked VHS
# 2                    An American Christmas Carol VHS
# 3  A NATION ADRIFT  A Chronicle of America's Prov...
# ...

# %%
df_test2['feature'].apply(type).unique()
# Out:
# array([<class 'list'>], dtype=object)
