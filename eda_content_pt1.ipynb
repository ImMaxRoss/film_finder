# %%
import pandas as pd

# %%
df = pd.read_csv('./data_original/reviews_meta.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203766 entries, 0 to 203765
# Data columns (total 19 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   category         203766 non-null  object
#  1   tech1            6 non-null       object
#  2   description      203766 non-null  object
#  3   fit              0 non-null       float64
#  4   title            203707 non-null  object
#  5   also_buy         203766 non-null  object
#  6   tech2            0 non-null       float64
#  7   brand            137335 non-null  object
#  8   feature          203766 non-null  object
#  9   rank             203766 non-null  object
#  10  also_view        203766 non-null  object
#  11  main_cat         203756 non-null  object
#  12  similar_item     0 non-null       float64
#  13  date             38 non-null      object
#  14  price            110745 non-null  object
#  15  asin             203766 non-null  object
# ...

# %%
df.head()
# Out:
#                     category tech1
# 0  ['Movies & TV', 'Movies']   NaN  \
# 1  ['Movies & TV', 'Movies']   NaN
# 2  ['Movies & TV', 'Movies']   NaN
# 3  ['Movies & TV', 'Movies']   NaN
# 4  ['Movies & TV', 'Movies']   NaN
#
#                                          description  fit
# 0                                                 []  NaN  \
# 1                                                 []  NaN
# 2  ['Disc 1: Flour Power (Scones; Shortcakes; Sou...  NaN
# 3  ['Barefoot Contessa Volume 2: On these three d...  NaN
# 4  ['Rise and Swine (Good Eats Vol. 7) includes b...  NaN
#
#                                                title
# 0                Understanding Seizures and Epilepsy  \
# 1  Spirit Led&mdash;Moving By Grace In The Holy S...
# 2                  My Fair Pastry (Good Eats Vol. 9)
# 3  Barefoot Contessa (with Ina Garten), Entertain...
# 4                  Rise and Swine (Good Eats Vol. 7)
#
# ...

# %%
df = df.drop(['tech1', 'fit', 'tech2', 'feature', 'main_cat', 'similar_item', 'date', 'price', 'imageURL', 'imageURLHighRes', ], axis=1)
df.head()
# Out:
#                     category
# 0  ['Movies & TV', 'Movies']  \
# 1  ['Movies & TV', 'Movies']
# 2  ['Movies & TV', 'Movies']
# 3  ['Movies & TV', 'Movies']
# 4  ['Movies & TV', 'Movies']
#
#                                          description
# 0                                                 []  \
# 1                                                 []
# 2  ['Disc 1: Flour Power (Scones; Shortcakes; Sou...
# 3  ['Barefoot Contessa Volume 2: On these three d...
# 4  ['Rise and Swine (Good Eats Vol. 7) includes b...
#
#                                                title
# 0                Understanding Seizures and Epilepsy  \
# 1  Spirit Led&mdash;Moving By Grace In The Holy S...
# 2                  My Fair Pastry (Good Eats Vol. 9)
# 3  Barefoot Contessa (with Ina Garten), Entertain...
# 4                  Rise and Swine (Good Eats Vol. 7)
#
#                                             also_buy        brand
# 0                                                 []          NaN  \
# ...

# %%
df['category'] = df['category'].str.strip('[]').str.split(', ')
df['category'] = df['category'].apply(lambda x: tuple(x))

df['also_buy'] = df['also_buy'].str.strip('[]').str.split(', ')
df['also_buy'] = df['also_buy'].apply(lambda x: tuple(x))

df['also_view'] = df['also_view'].str.strip('[]').str.split(', ')
df['also_view'] = df['also_view'].apply(lambda x: tuple(x))

df['description'] = df['description'].apply(lambda x: x[1:-1])

# %%
df.drop_duplicates(inplace=True)

# %%
df.to_csv('./data/meta_content.csv', encoding='utf-8', index=False)
